# %% [markdown]
# ## GPT 2 Pretrained Model Story Generation

# %%
#Install the required library updates for both accelerate and transformers
#from huggingface
# !pip install -U accelerate
# !pip install -U transformers
# Out:
# Collecting accelerate
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.25.0
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Collecting transformers
#   Downloading transformers-4.36.2-py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# Successfully installed transformers-4.36.2

# %%
#Set the device to CUDA (or GPU) for processing
import torch

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)
print(f'Using Device: {device}')
# Out:
# Using Device: cuda

# %%
#Import the required GPT2 modules from the transformers library for running
#GPT2 model
from transformers import GPT2Tokenizer,GPT2LMHeadModel,TrainingArguments,Trainer,DataCollatorWithPadding

from torch.utils.data import Dataset

# If a local copy of the pretrained model is unavailable, use the following two lines to load the model and tokenizer to load it directly from Huggingface:

# tokenizer = GPT2Tokenizer.from_pretrained("gpt2-medium")
# model = GPT2LMHeadModel.from_pretrained("gpt2-medium")

tokenizer = GPT2Tokenizer.from_pretrained("//content/drive/MyDrive/Colab Notebooks/Story Generator/gpt2default/tokenizer")
model = GPT2LMHeadModel.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Story Generator/gpt2default/model")

if tokenizer.pad_token is None:
  tokenizer.pad_token = tokenizer.eos_token
  tokenizer.pad_token_id = tokenizer.eos_token_id

#Send the model to process within the GPU
model.cuda()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 1024)
#     (wpe): Embedding(1024, 1024)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-23): 24 x GPT2Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=50257, bias=False)
# )

# %% [markdown]
# ## Evaluating the pretrained model with 10 prompts

# %%
#Set the model to evaluate to run prompts on the model for generation
model.eval()

#Set prompt text for model
prompt_text = "An adventurer from the east"

#Convert the prompt text to tokens and add the attention mask
input_ids = tokenizer(prompt_text, return_tensors = "pt").input_ids
attention_mask = tokenizer(
    prompt_text, return_tensors="pt"
).attention_mask

#Send converted prompt and attention mask to GPU
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)


#Generate the output from the model based on the parameter set here
output = model.generate(
    input_ids = input_ids,
    attention_mask = attention_mask,
    pad_token_id = tokenizer.pad_token_id,
    max_length = 1024,
    num_beams = 10,
    min_length = 1000,
    temperature = 3.5,
    top_k = 50,
    do_sample = True,
)


generated_text = tokenizer.decode(output[0],skip_special_tokens = True)

print(generated_text)
# Out:
# An adventurer from the east has gone down to investigate the strange phenomena that seems to have taken place all over the kingdom. He is caught up in the chaos, and if he does not rescue his kidnapped daughter, he'll be doomed!
#
#
# DRAGON OAKS' STORY
#
# Experience the original Dragon Oaks game with Dragon Oaks 2 in the stunning 1.5D style. Go back to your village, get into battle and take control of the heroes to keep your village from becoming devoured!
#
# CONSTRUCTION:
#
# 1. Select your character, right click
#
# 2. Drag the hero you wish to construct to your canvas
#
# 3. Right click and select 'Create Component.'
#
# 4. Select your character, then drag it onto the component you selected
#
# This is not the full game. All the components you selected will remain in the canvas
#
# Note that some components are not in game, but it is a playable prototype
#
# DOWNLOAD
#
# DOWNLOAD DEMO FILE
#
# To install the new version, just download the Demofile
#
# To upgrade the game you can either do the following
#
# Just click the update button (the logo on the left) or follow a guide
#
# DOWNLOAD
#
# DOWNLOAD DEMOTION
#
# DOWNLOAD DEMOBYSP
#
# To see the latest releases of the game.
#
# You can also see the current list of previous releases as well as the upcoming releases:
#
# DOWNLOAD
#
# DOWNLOAD DEMOTION DOWNLOAD
#
# This mod is an Open Source version, it is not an in-game game. You can download any of these files from the Releases page
#
# Credits:
#
# 1. Open Source Gameplay Mod - www.opensourcegamegame.com Thanks to the people who made it, we all helped the development process and this mod is very important for us and the community. Thank you to the amazing community that helped develop this game! Thanks to the game designer and programmers who came out with great tools for us to make this mod.
#
# We need to thank everyone who bought the game for the amazing game experience you got, we really wish you the best for the future and hope that the game is enjoyable to play.
#
# Thanks to all people involved in the game development, we would have not be where we where we are today if we would have just picked up a game editor.
#
# And finally we thank the game developers who released the game, we really hope that they improve upon our game more and make it even better. Without the game developers working so hard we wouldn't have managed such a massive release and this would not have happened because of our friends. We couldn't take care of ourselves if this game wasn't made. You guys are just amazing, thank you so much guys, hope you keep making awesome games for the games we dream about! ^^
#
#
# 2. Art from the developers of the game - www.dragonsouparts.com Thank for playing! We are so glad you guys liked this project and think it's very awesome! Please send us some praise and let's see what you come up with in future projects too!
#
# 3. Support to the team: Dragon Oaks is made by a team of dedicated people all of whom have done it their own way. You can visit the website about the team and join in the conversation on our forum.
#
# 4. Thanks to the people in our community so we can try out the new game. If you want to suggest a project or ask for help just leave a comment here.
#
# Thanks again for your support! And if you like the game please tell your friends so it can come to your attention when more new games become available in the future. Have fun!
#
# -The game dev team at Dragon Oaks
#
# -Support us on Steam and the Steam community forums. Thanks for playing! You are our most generous fan!
#
# -If you want to contact us about this or any other project, the email address is - dragonsoup@gmx.net or drop us a note at - dragonsoup(AT)devo...dwoods(D)o...games (DM)
#
# -We ask that you play the whole game in full screen window mode rather than the full screen window in low resolution. Thanks for playing dragon oaks, we greatly appreciate your enthusiasm and help us develop and release the game!
#
#
# Thanks for listening and playing!
#
# -Dragon Oaks Game team
#
#
# We will reply to emails once it has been received!
#
# Like this mod? Follow me on Facebook for a sneak peak at the next big open source game! Just go to the dragon oaks link below and hit "Like"
#
#
# http://dragonoak.com/ Like this mod?Follow me on Facebook for a sneak peak at the next big open source game! Just go to the dragon oaks link below and hit "Like"
#
# If you have any questions or

# %%
#Set the model to evaluate to run prompts on the model for generation
model.eval()

prompt_text = "The girl had a dream of flying"

#Convert the prompt text to tokens and add the attention mask
input_ids = tokenizer(prompt_text, return_tensors = "pt").input_ids
attention_mask = tokenizer(
    prompt_text, return_tensors="pt"
).attention_mask

#Send converted prompt and attention mask to GPU
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)


#Generate the output from the model based on the parameter set here
output = model.generate(
    input_ids = input_ids,
    attention_mask = attention_mask,
    pad_token_id = tokenizer.pad_token_id,
    max_length = 1024,
    num_beams = 10,
    min_length = 1000,
    temperature = 3.5,
    top_k = 50,
    do_sample = True,
)


generated_text = tokenizer.decode(output[0],skip_special_tokens = True)

print(generated_text)
# Out:
# The girl had a dream of flying through the sky and going to Earth. But when she came, she found the world she was dreaming of was still in the past. The only person she knows in the past is she is from the past.
#
# She had to destroy her past life, learn how to live again. She had to become stronger to become a savior. She had to kill her own mother and take her place at his side.
#
# And so she did, killing her father who was now only a distant past memory. Then she ran away from home.
#
# It was only now, twenty five years had passed, that she finally realized just how bad this nightmare her past life had brought about and that she had gotten even more screwed up in her later years. She had always wanted to know what happened to the Earth before it was wiped out so that she can fix what happened to it to get back on track. At this point in the adventure, it had never even occurred to her why she should be so determined to fix all of the destruction she caused in her earlier life. That was until she realized the full scope of it all, but didn't care anymore, because he was her brother and she still loved him so much. She wasn't sure if she really loved him at that moment. But now he seemed to find her as a person. She wasn't sure if there would always be time to find out but maybe that would eventually happen when she realized the extent of what she was truly capable of. In any event, it didn't have to happen that way because she didn't care at all anymore, because even though she thought she loved him and she wanted to show him love again, she knew that it was only now because she realized the magnitude of the problem she had already created that she could actually make another attempt at fixing things, just with a different direction.
#
# So, she spent all of her savings to purchase a plane, with the understanding that at some point the world would be saved. After five years and six trips around the world, she eventually bought a real-life one and flew it to England to become a pilot, but it had already come to the point where it wouldn't fly at all anymore. There was a plane she wasn't happy about but she figured she would live with that for the future. Just as she was thinking about this when the helicopter finally arrived at the location they needed to fix the place, she felt something and she turned around to see the girl who'd made the trip to save it from the wrecking ball had appeared before her with her back to them.
#
# "I know about you. I've heard a lot about you. This was your first adventure. I think I'm not from earth anymore. I think. You must be pretty surprised."
#
# "Um...yes. I am. Sorry, I felt a bit bad."
#
# "You didn't say you didn't care about us."
#
# The girl looked embarrassed. "No...I do. I wanted to see you. I wanted to help you."
#
# "It was a dream." And this time, she didn't apologize. She told it as it actually happened.
#
# The man looked embarrassed, his face turning red. "I never had that dream. Just the one where you showed up in my life. It was for you. In my dreams. Just for you." The boy sighed. "It was always for me. Before this, I just wanted to become something better. If I could change everything, I would have just done that and had a great life for you." The man sighed again.
#
# "And I think the world would be different if you were alive," she said to him sadly. "Why did you do such a awful thing?"
#
# When the boy smiled, he seemed surprised and just sort of looked at her as if that were normal, and then he laughed. "It was because you needed to. It was time for me to come back. I needed that help. To live for the first time as a normal person. And that is when things changed."
#
# It was the first smile on his face she'd seen since that dream, so she felt like she was seeing that again. It was a genuine, warm smile, not like it was faked. He didn't have to try too hard. He was willing to meet her in her dream-state. And she could tell that even though the dream was unreal, it still had meaning to him, despite the fact the dream wasn't true at that point.
#
# "What is happening?" she asked him, when she didn't have any more time to talk at all.
#
# "Well, I'm coming with you now. If this dream can help you get home to your family, all of this can change." She stood up, and when she came in, her eyes met the man she'd once loved. The man's face, now filled with wonder, looked a

# %%
#Set the model to evaluate to run prompts on the model for generation
model.eval()

prompt_text = "The dragon roared mightily"

#Convert the prompt text to tokens and add the attention mask
input_ids = tokenizer(prompt_text, return_tensors = "pt").input_ids
attention_mask = tokenizer(
    prompt_text, return_tensors="pt"
).attention_mask

#Send converted prompt and attention mask to GPU
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)


#Generate the output from the model based on the parameter set here
output = model.generate(
    input_ids = input_ids,
    attention_mask = attention_mask,
    pad_token_id = tokenizer.pad_token_id,
    max_length = 1024,
    num_beams = 10,
    min_length = 1000,
    temperature = 3.5,
    top_k = 50,
    do_sample = True,
)


generated_text = tokenizer.decode(output[0],skip_special_tokens = True)

print(generated_text)
# Out:
# The dragon roared mightily before unleashing a massive roar, causing most of the soldiers at the front to be startled and fall to the ground, who were only able to look with surprise at an intense golden light glinting through his body, which engulfed the entire mountain range, with such a terrifying aura emitting from it. At that moment…
# This was truly an incredible energy, as though there were dragons in its midst. This caused the entire mountain region to go dark.
# "Wooo!"
# A huge group of golden dragons exploded from the mountain ridge in front. Each one, seemed to be full of life and vitality. The golden dragon's roar was like the noise of a flock of turkeys calling out in their thousands, and it left a deep scar on its opponents' bodies, causing them to shudder in pain. In contrast to the shockwaves it sent through every single soldier and every single human, all of them were struck by this one powerful blast.
# "Nyah…"
# "What is this!"
# "Woooooo!"…
# All the soldiers who were trapped at the back were startled as they were blown away the mountain ridge by wind and lightning. The mountain ridges surrounding them became a huge, deadly wall of lightning.
# As for the remaining soldiers and soldiers who had escaped, they began to panic as they were hit by one after another blast of lightning before they lost consciousness from their agony.
# As of the time the fire began to spread, around 150,000 people were already dead or wounded on the road, and it had only taken around 30 seconds for the entire scene to transform into a death-trap. It was obvious that after this gigantic explosion, the air had completely lost its resistance and had completely evaporated due to the sheer force of the thundering thunder.
# "Nyah…"
# All of the soldiers who were thrown into the air while flying from the front started to scream as their bodies began to go numb from the shockwaves. The most important point of all was…
# "Peng, peng, peng…"
# The ground immediately shook from their impact with it, causing everything on the surface of the mountain to shake. Even the rock underneath their feet started to split into numerous fragments, making them feel like they could fall off at any moment.
# Even before the soldiers could get up from the mountain ridges that were now falling down, a huge amount of blood started to come out of the mountain, and were spilling out in front of the soldiers who were blown away by the thunder. As long as they stopped moving, they were doomed to die. The sky in the surrounding area was covered in the blood of the dead, and it wasn't long until the blood was falling to the ground in front of them.
# They couldn't hear any sound coming from anything inside the cave, so the soldiers could only watch as the cave began to slowly collapse.
# "Nyah~…."
# The soldiers who were caught in that wall of lightning were thrown to the back by lightning during the thunderstorm. In spite of the pain they were experiencing, they were already too exhausted to fight back.
#Convert the prompt text to tokens and add the attention mask
input_ids = tokenizer(prompt_text, return_tensors = "pt").input_ids
attention_mask = tokenizer(
    prompt_text, return_tensors="pt"
).attention_mask

#Send converted prompt and attention mask to GPU
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)


#Generate the output from the model based on the parameter set here
output = model.generate(
    input_ids = input_ids,
    attention_mask = attention_mask,
    pad_token_id = tokenizer.pad_token_id,
    max_length = 1024,
    num_beams = 10,
    min_length = 1000,
    temperature = 3.5,
    top_k = 50,
    do_sample = True,
)


generated_text = tokenizer.decode(output[0],skip_special_tokens = True)

print(generated_text)
# Out:
# The earthshaker beat his drum fiercely. Then he drew his sword.
#
# "I want you to join my cause. Do not let the light of the blade take your life. I need you. You will die before you allow yourself to be captured by the dragon."
#
# "But what if the light of my blade doesn't kill you? If I die here, your body will be left here, sealed away in some dark cave deep in the mountains for all eternity to live on, in agony and despair. I would rather die by your side than submit to this torture. In truth, we are all in this place, together, to save the world. So let me sacrifice myself before the blade."
#
# The sword's gleaming blade was thrust into the earth.
#
# The earthshaker's eyes gleamed golden, and his eyes rolled, as he watched the dying earth pony, and felt the pain and anger in the earthshaker. As the earthshaker's blade plunged into his flesh, his eyes sparkled.
#
# The world shuddered, but he didn't get angry. The death was too merciful.
#
# Then he saw the earth shaking, as if some unseen force were trying to shake apart all life on earth. "You're an animal. You have no feelings. You don't even have a soul to give meaning to what you are now. Let me save you."
#
# At that, the earthshaker's eyes flashed black, and he fell silent, stunned by the vision. "I...I can't go with you."
#
# The earthshaker knew that he couldn't. "I will kill you. The earth will destroy me. You'll live on as nothing. I'll be gone and forgotten."
#
# And the earth's earth was about to destroy him, the earth's earth. But the earth was alive. It wasn't a dream, this world was alive to him, and he didn't think about anything else. It would be impossible to kill this world. It would burn the earth to ash, and the earth would bury him. He couldn't live forever with it. If it happened, it was a terrible fate indeed. The earth would tear him to pieces too, and he knew he couldn't help it. Or if he was to die on the dragon's back, the earth would bury him too.
#
# He was tired. He could barely move. And his eyes were red.
#
# "This is the only chance. I will not give you away. You are not a coward, you are not a weakling, a weakling won't surrender. This world would not be my home, and it's not mine, and I...I don't have to die."
#
# His body was shaking as if it were on a rampage. It had been an hour since he'd last fed it. How could he resist the dragon? It was more likely the dragon would kill him when he was tired anyway. There was just no chance in hell that this world could stay alive for much longer if the earth's earth did. He wouldn't listen to any of the ponies in danger, and neither would the dragons. He could not keep this world from falling. The earth had to die. "No!" he said fiercely. "I...I can't. How am I going to save you?! I've given up everything I've ever known! I'll die here without a purpose! Even if it means my entire life is wasted, then that is the only way to save the world! All...all I ask is...I want to live! Let me see you...let me kiss your face."
#
# "You're...are you going?"
#
# The earthshaker turned around, eyes shining with anger, as he saw her face. "It doesn't matter what kind of pony you are. What matters is you. You're not me. You're nothing. I have never known you to have a reason. You don't even know if I care. And when I see you, it makes me even worse. And you still won't believe what you see. Is that a good sign?" He held her close.
#
# The earthshaker reached down and touched her head. "If...if you will give me a moment to...what?" he mumbled into her ear. "Let's talk about something important. About what will make you save me. You can tell me whatever you want. But before I do I need to...do something."
#
# "What should I?"
#
# The ground shudders again, and he stands up. He looks down at the earth pony behind him. "You're going to be my backup. I'll keep you safe, but don't worry about me. I'll still protect you from the dragon. But when I finally return, I'll protect you from the very dragon that will destroy your life to steal it from you. Then you'll be mine.

# %%
model.eval()

prompt_text = 'The great warrior Nihara unsheathed her sword and cried out: "How dare you hurt my bubs! Now you will feel my wrath you robot chicken".'

#Convert the prompt text to tokens and add the attention mask
input_ids = tokenizer(prompt_text, return_tensors = "pt").input_ids
attention_mask = tokenizer(
    prompt_text, return_tensors="pt"
).attention_mask

#Send converted prompt and attention mask to GPU
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)


#Generate the output from the model based on the parameter set here
output = model.generate(
    input_ids = input_ids,
    attention_mask = attention_mask,
    pad_token_id = tokenizer.pad_token_id,
    max_length = 1024,
    num_beams = 10,
    min_length = 1000,
    temperature = 3.5,
    top_k = 50,
    do_sample = True,
)


generated_text = tokenizer.decode(output[0],skip_special_tokens = True)

print(generated_text)
# Out:
# The great warrior Nihara unsheathed her sword and cried out: "How dare you hurt my bubs! Now you will feel my wrath you robot chicken".
#
# Afterwards, Nihara was brought back to this world and is now waiting to die. All of the prisoners were locked up as well. The next day she was brought here along with three others, and was sentenced to life imprisonment in the dungeon. After being imprisoned for almost one full day, they were finally released in the evening. A new prisoner came along and this one was even crazier. He was even bigger, longer, and taller than Nihara. He was also the only prisoner in his world who did not appear from his own world.
#
# Nihara was sent back to earth.
#
# "I didn't even have any words. How could I think I deserved to go to such a wretched place? What kind of idiot did Nihara serve? I wonder if they would have let her go back if I didn't have any hatred in me." Shizuka told the people in her room when she returned.
#
# "Are you still alive? Do you remember when I brought you back?" Taka-kun asked.
#
# "They let her go because she was a dangerous criminal with no regard for mankind. It was only a matter of time before they finally decided that she couldn't be trusted to run a shop."
#
# "So she was brought back like this to serve the Demon God Nihara Nihara. Is there any way to free her from life imprisonment for the next few years?" Nita asked.
#
# "I'm not aware of how long they'll take to get her out." Sōma agreed.
#
# "Do you care? She was my only one. Do you believe she would have a chance to escape if she died? I don't want the Demon God Nihara Nihara back in any shape, size, color or shape you wish it to be." Yui-chan asked.
#
# "Why would we allow her back to our world?" Nitta demanded. "Do you not know that we are humans and can't be spared by people like her? Even worse, why would you think she deserves to serve the Demon God even more? It really is horrible!"
#
# Tsukishima decided to let her out. She was allowed to move freely inside the dungeon to do her work while being allowed to go outside to kill any Demons that appeared. She even managed to escape in time. However she didn't tell anyone the truth about what happened outside the dungeon. The guards tried to attack her every time they came to check on her. One of them was injured and tried to leave the city. However she continued working despite that. Eventually, all the guards were so scared that they just stopped attacking and just stood their ground until she escaped.
#
# "Tsukishima, you had no idea what you'd been playing with!" Shizuka yelled out, "You let her die like this, and she should have just been killed in front of us. We are the one who must pay for this. You have to promise not to kill the ones who killed her for nothing. Now that we have the Demon Gods out, it would be great to not only kill them, but the people who are in the same room with them to kill the other ones too. You must protect those who are suffering, no matter what!"
#
# After that, Tsuishima ended the trial for everyone and sent Yui-chan off to her world again. She wasn't quite able to save Nihara from getting killed by Yuki, but in the end Yuki managed to save her life. Not long after she returned, they arrived at the Great Temple to start their new lives.
#
# "The first thing I wish to do is to teach the Demon God to forgive us humans by making him see that we, the humans, can become gods." Yuki promised. "One day, if you do this you too would become the god, and I believe in this, that's why I don't think you would ever harm us humans again. I promise to stop doing that. It would be really hard for you if I don't."
#
# "Don't forget your dreams. I won't try and kill you again soon, but that doesn't mean you won't try again. I promise to keep that promise." She said.
#
# As a way to honor Niki, Tsuishima made sure that there were a lot of toys in her household. A lot of Niki's favorite things were always around her house to be enjoyed by everyone. The ones that would become her greatest heroes.
#
# Yui-chan got her own house to enjoy. She even started building up her own castle inside her own home and started serving her own demons as her knights and guards. Yui-chan made sure everyone's house was very clean, even when it wasn't her house it would always be cleaned
