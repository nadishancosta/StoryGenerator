# %% [markdown]
# ## GPT 2 Pretrained model generations

# %% [markdown]
# Last modified: 06-01-2024
#
# Name: Mahamuge Dinendra Nadishan Costa
#
# UWE Student Number: 13030224

# %%
#Install the required library updates for both accelerate and transformers
#from huggingface
# !pip install -U accelerate
# !pip install -U transformers

# This resets the environment automatically to apply the installations above.
import os
os.kill(os.getpid(), 9)
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.25.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.36.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Set the device to CUDA (or GPU) for processing
import torch

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)
print(f'Using Device: {device}')
# Out:
# Using Device: cuda

# %%
#Import the required GPT2 modules from the transformers library for running
#GPT2 model
from transformers import GPT2Tokenizer,GPT2LMHeadModel,TrainingArguments,Trainer,DataCollatorWithPadding

from torch.utils.data import Dataset



# If a local copy of the fine-tuned model is unavailable, use the following two lines to load the model and tokenizer to load it directly from Huggingface:

# tokenizer = GPT2Tokenizer.from_pretrained("gpt2-medium")
# model = GPT2LMHeadModel.from_pretrained("gpt2-medium")

tokenizer = GPT2Tokenizer.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Story Gen/GPT2 Pretrained/tokenizer")
model = GPT2LMHeadModel.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Story Gen/GPT2 Pretrained/model")



# Run the following to load the fine-tuned model on stories with original lengths
# tokenizer = GPT2Tokenizer.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Story Gen/GPT 2 Finetuned/tokenizer")
# model = GPT2LMHeadModel.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Story Gen/GPT 2 Finetuned/model")


# Run following two lines to load the fine tuned model trained on equivalent length stories
# tokenizer = GPT2Tokenizer.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Story Gen/GPT 2 Finetuned with data balance/tokenizer")
# model = GPT2LMHeadModel.from_pretrained("/content/drive/MyDrive/Colab Notebooks/Story Gen/GPT 2 Finetuned with data balance/model")



if tokenizer.pad_token is None:
  tokenizer.pad_token = tokenizer.eos_token
  tokenizer.pad_token_id = tokenizer.eos_token_id

#Send the model to process within the GPU
model.cuda()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 1024)
#     (wpe): Embedding(1024, 1024)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-23): 24 x GPT2Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=50257, bias=False)
# )

# %% [markdown]
# ## Evaluating the fine-tuned model with 10 prompts

# %%
#Set the model to evaluate to run prompts on the model for generation
model.eval()

#Set prompt text for model
prompt_text = "He drew his sword and pointed at the peculiar"

#Convert the prompt text to tokens and add the attention mask
input_ids = tokenizer(prompt_text, return_tensors = "pt").input_ids
attention_mask = tokenizer(
    prompt_text, return_tensors="pt"
).attention_mask

#Send converted prompt and attention mask to GPU
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)


#Generate the output from the model based on the parameter set here
output = model.generate(
    input_ids = input_ids,
    attention_mask = attention_mask,
    pad_token_id = tokenizer.pad_token_id,
    max_length = 1024,
    num_beams = 10,
    min_length = 1000,
    temperature = 3.5,
    top_k = 50,
    do_sample = True,
)


generated_text = tokenizer.decode(output[0],skip_special_tokens = True)

print(generated_text)
# Out:
# He drew his sword and pointed at the peculiar young lady. "Do what you need to in this town!" he roared. "We'll give it some time."
#
#
# * * * * *
#
#
# When the battle had gone on for three days without the use of gunfire, it was evident that the enemy army was not as powerful as he had been led to believe. The enemy did not possess a strong force of cavalry, as they often did during the day, let alone the infantry, but it was still capable of pushing the enemy back so far. The general felt it was imperative that they make use of every available source in their power, and on this very day his troops found themselves completely surrounded in their own camp.
#
#
# The soldier who had led up to the enemy's position ordered that the prisoners of war come to his relief, while he himself marched to his camp, intending to relieve his comrades in the meantime. To his utter amazement, the wounded and sick found themselves outside his tent, and many of them soon lost consciousness. When the guards found out about this, they were furious with their own leader, saying that they refused to be the first men to go to relief.
#
#
# On entering the camp, some thirty men were ordered into a small fire-place, which served as their shelter. A handful of soldiers came forward, but the general had already sent to them. Some of the prisoners stood up at one time, and others turned their backs, as if unsure of their own strength and lack of ammunition. As the general walked by the prisoners, a man in one of the first groups turned his back to him, but the general spoke. "You want to come with?"
#
#
# "Not with," the prisoner answered, but he did not say what he expected from the general of the Third Army, nor did he know who it was. In fact, he had no specific order to take the prisoners. He thought it very odd, that the prisoner, without realizing it, had come to serve as his bodyguard. He felt a deep sense of responsibility for his fellow soldiers, for he had been the cause of what had happened. But then, he felt, he was only doing what the man would have done, had they been in his position. The officer who led him walked over and put his arm around the soldier's shoulders. "You'll be safe here," he said, "because I'm your General."
#
#
# They sat there in silence for quite a while, each soldier trying to grasp at what had just happened. The general did not speak any more. He was beginning to tire, and finally, his staff officer came up to him, placed a hand on his thigh. "I think it would be best if you took the prisoner to a certain area," he instructed him. "He may still be dangerous, but we shall see what is in store for him. Now, you can leave if you wish, but the general will stay for a while longer." It was obvious that this was the last opportunity the prisoners of war to enjoy a brief respite. By now they were on their way to their appointed place. It was as though he had ordered them to get back on horseback. "We'll be back as quickly as we can," he assured them. After a moment or two, some of the prisoners left the fire-place, while others sat down at their camp. The other soldiers were not aware that he had gone away until he was out of sight and had returned with the men he had taken with him into the enemy's camp. They were confused as to why they were left in the middle of nowhere, but at least now the general would know where his force was located and which side of the front was at the head.
#
#
# In order to be able to count all the soldiers in his command, the general ordered a small board with numbers to be placed all around him. These numbers were numbered from 1 to 99, and each one was to count to twenty from 1 to 20, in descending order of importance, and the general himself would be counted one by one every ten steps. The number 99 stood for the General of the Third Army. There were about one hundred of them at his command, all with their numbers printed out. The men in front were numbered on the board, with the few behind them counting to nine. The general also made sure every man had a uniform and clothes, so that they could be recognized and, above all, that they would be able to take care of themselves, if anything happened. At the head of this column stood the general, with all the men in the front, and then each man at the front had a weapon in his hand, and could fire at any time without disturbing his colleagues. The people were separated into groups, each with a flag, and the general set up his tent as the camp commander for all those who wanted him out.
#
#
# The general's instructions to his men were simple: lie down and lay down on their sides.

# %%
#Set the model to evaluate to run prompts on the model for generation
model.eval()

prompt_text = '''Nihara the warrior princess was calm in the face of danger.
No one dared challenge her now.
'''


#Convert the prompt text to tokens and add the attention mask
input_ids = tokenizer(prompt_text, return_tensors = "pt").input_ids
attention_mask = tokenizer(
    prompt_text, return_tensors="pt"
).attention_mask

#Send converted prompt and attention mask to GPU
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)


#Generate the output from the model based on the parameter set here
output = model.generate(
    input_ids = input_ids,
    attention_mask = attention_mask,
    pad_token_id = tokenizer.pad_token_id,
    max_length = 1024,
    num_beams = 10,
    min_length = 1000,
    temperature = 3.5,
    top_k = 50,
    do_sample = True,
)


generated_text = tokenizer.decode(output[0],skip_special_tokens = True)



print(generated_text)
# Out:
# Nihara the warrior princess was calm in the face of danger.
# No one dared challenge her now.
# "I will defeat you. And if you defeat me, I will destroy the village. But no matter how… I will keep you as a slave forever."
# Kudou sighed as his body shook. But for some reason, even as he spoke he felt that he could not speak in such a violent tone. He was at a loss how he could make it through the battle while maintaining his cool composure.
# "... It really is amazing that you have the resolve to destroy me. That's a sign of your strength, not that I can't kill you, but that's not the point of this battle. It's about you killing yourself. Once you kill yourself, then there will be no stopping you from turning the village upside down. That's all there is, that's all we can promise you. If that is what needs to happen to me, then that is the will of my king."
# While he spoke, he extended his sword.
# ...
# "... You don't believe that I can do it, though?"
# When he turned around to confront Hachiman, Naofumi felt something strange. He felt Naofu's breath on the sword and it was even more than usual. He wanted to ask Hachiman about that... but how would he get the sword?
# "No, that isn't the problem. I won't just sit idly in front of you like before. What I'm asking you is whether your resolve can be said to outweigh your ability. That is the true test. Whether you can reach your goal now or will you fail to do it when you make a mistake of such magnitude? Are you that strong? Are we that strong in the end?"
# With that said, Naofumi looked up to Noda.
# "If you want, I'm also going to make sure it's this way as well."
# Naofumi looked around the village.
# In the city where he was living, there were people gathered together in groups.
# "In the end... why do they continue to say that Naofumi can't win? Well, the fact they didn't want him to enter the village before was because they didn't think that there would be a miracle. Now, I can see that they are a bit wrong. If there would be no miracle, everyone would realize it. But that is not possible to happen right now, so they continue to say it's all possible. However, that is not the kind of reasoning I use. I'm only interested in whether this is something we can accomplish today."
# "What?"
# "If the people can realize that this is only possible if they can believe in it, then I see no reason why we cannot do it."
# "Exactly."
# "Then I will do it tomorrow and make that village look as if nothing is wrong. This is all I ask of all of you. There will be no turning back from that. After all, there was no way Naofumi could fight against me."
# "That doesn't sound like a reasonable reason for all of us."
# "And if it's not a reasonable reason... are you willing to sacrifice your dignity, and your strength to save them?"
# Noda's question was unexpected. He was surprised at the sudden calmness in that voice. He wasn't expecting that from this man.
# "To be honest, I do not know whether I believe in this or not either. But I want to save my people. They are my children. I will not abandon them just because you ask me something that you think isn't right. You may think this is a lie, but that will not make you change your viewpoint."
# It was surprising for a man of the royal line to say that after all this. Hachiman had fought against Noda and fought alongside him, so that was not an easy thing for him to understand.
# "I don't really have an easy time believing that there isn't any reason to change. Even now, if I'm told that the whole world is going to go to hell for something like this and there is no way we will win against it, then I am convinced. Or maybe, just because I am convinced, I am unable to believe in miracles. I really can't do that."
# "... You seem to have lost that resolve in front of all this. A man of this country should be more of a warrior hero than this... I suppose that may not mean that much of a stretch for a man like you though. Even so, I wonder if you're really that calm as well? Is that all because you're afraid that someday you won't survive?"
# "... Naofumi-sama."
# "I want to see the sun rise on the same day."
# "And how about when it does? How about at sunrise? I'm looking forward to that."
# "Is that something that you

# %%
#Set the model to evaluate to run prompts on the model for generation
model.eval()

prompt_text = "And so it was the beginning of a beautiful friendship. Perhaps even something more. "

#Convert the prompt text to tokens and add the attention mask
input_ids = tokenizer(prompt_text, return_tensors = "pt").input_ids
attention_mask = tokenizer(
    prompt_text, return_tensors="pt"
).attention_mask

#Send converted prompt and attention mask to GPU
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)


#Generate the output from the model based on the parameter set here
output = model.generate(
    input_ids = input_ids,
    attention_mask = attention_mask,
    pad_token_id = tokenizer.pad_token_id,
    max_length = 1024,
    num_beams = 10,
    min_length = 1000,
    temperature = 3.5,
    top_k = 50,
    do_sample = True,
)


generated_text = tokenizer.decode(output[0],skip_special_tokens = True)

print(generated_text)
# Out:
# And so it was the beginning of a beautiful friendship. Perhaps even something more.  I asked her whether she ever thought back to that morning, what she would have asked her, if she were alive at this moment. She smiled and replied:  "Yes, you would have."
# "Well I would have wanted to say yes. I'm sure we could have talked about everything. But there was something else we wanted. Something we never could have accomplished together. Something we never could have done together and I know how much that's hurt. "  Her eyes lit up. "I know, it's something you haven't fully understood."   She paused and took in a deep breath and said, "I'm afraid I know. I don't want it to make you sad. I don't have anything to talk about. I think I'm going to take a bullet for you."   It felt good to see such compassion and compassion in someone. Something changed.   I knew now that this woman truly cared and understood me that much. For that time, she could be with me even if only briefly.   "Thank you again," I said, "I think I'm ready for our little trip."   She laughed and thanked me and then we drove back home together. I couldn't even begin to imagine how wonderful she felt with me.
# I made my way through that night wondering what the hell happened and what I should have done. I had no clue how to explain the death to a grieving parent of a child killed in action. I had no plan for the days ahead.  It wasn't just my wife and two wonderful children. It was my entire life. I tried to get back on the path I left. But I was a broken child. It wasn't fair that I had to live with such loss.
# There are days when you want to walk away but there are times when the best thing you can do is keep holding onto that fire.  It isn't over. It doesn't take much to kick it.
# Some day I'm going to have the fire back.  Some day we'll be sitting together in a diner and talk about this.
# Whatever you do, remember the woman I lost. She was my mom. And my mom was my friend.
to him that I wanted him to come out from under the tree, and asked if he should go to see me. He hesitated, then he went to the tree and told me what had happened to my dear friend. That was all. I did not see him again for many months, even after the tragedy which was happening in my heart, and when I called my mother she said I had lost him, but even now she is waiting for me to hear the news. My mother and brother did not get to know one another very well until they left the village; I am glad that in some ways I had a good memory of my young friend. My father never forgot me, but now that I am at last going home again, I will remember him more vividly. I am quite certain that my brother will soon be back at the hospital, and he may even know me, and perhaps he will talk to me a little again too. I am glad he is alive because he was one of the good men who helped us. Now that I have spoken of my brother, of my brother's life gone before, of my brother who was the brother of my brother who was among the survivors, we can say that there will be no greater tragedy in this land than that which befell "my dear friend," a Jew who was trying to take the life of his Jewish friend. How do you say to a man who was innocent to be guilty of the crime with which he died for the love of his community? And if the Jew who was innocent had been allowed to carry out the killing in question and done as he wished, would not that crime have remained? If it had, then he would not have lived at the same ...

# %%
#Set the model to evaluate to run prompts on the model for generation
model.eval()

prompt_text = "Fly you fools!"

#Convert the prompt text to tokens and add the attention mask
input_ids = tokenizer(prompt_text, return_tensors = "pt").input_ids
attention_mask = tokenizer(
    prompt_text, return_tensors="pt"
).attention_mask

#Send converted prompt and attention mask to GPU
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)


#Generate the output from the model based on the parameter set here
output = model.generate(
    input_ids = input_ids,
    attention_mask = attention_mask,
    pad_token_id = tokenizer.pad_token_id,
    max_length = 1024,
    num_beams = 10,
    min_length = 1000,
    temperature = 3.5,
    top_k = 50,
    do_sample = True,
)


generated_text = tokenizer.decode(output[0],skip_special_tokens = True)

print(generated_text)
# Out:
# Fly you fools!
#
# The world must not know what it has heard..."
#
# —Chorus of the song by the Talking Heads
#
# I'm about to go on a ride,
#
# The sound of your bells on a summer's night!
#
# You may not go home, I'm home now.
#
# But the stars and the wind
#
# All sing for us, the way we've been trained
#
# To dream dreams in a dreamless night.
#
# You know, dreams do have meaning—
#
# But here I am at last, here I am.
#
# When you're tired, the music is over.
#
# You know…
#
# —Chorus of The Velvet Underground song "Dreams" by The Velvet Underground
#
#
# I thought I had gone home,
#
# I'd had enough of home, a cold and damp place, but now...
#
# You've got my heart, my throat, all that I have,
#
# It was an awful place to die.
#
# But we're free to take our breath away
#
# And I don't want to go, I'll just wait here,
#
# There ain't a chance in the world, I'll keep on dreaming...
#
# …I just keep on dreaming...
#
# I'll go on dreaming when it's just me and you And when the time comes you'll want to see,
#
# I'll hold on to it, just in case...
#
# I wish someone would keep on dreaming about me And I wish someday you'll want to see,
#
# I'll want to hold onto it...
#
# ...until the time comes to forget...
#
# I just want to forget, I just kept on dreaming and never got tired
#
# (I hope it lasts until the last breath... )
#
# [Chorus of The Velvet Underground song]
#
#
# "Dreams I've made when the sky is black and I'm alone in the woods I'm not allowed to dream of it I've never dreamed the dream of being free of home
#
# But here in this cold, gray night I've lost myself to my dream I've dreamed dreams and never quite realized it
#
# You've taught me to trust myself, I've learned to trust me you've taught me to know and trust you
#
# Dreams, when the clouds come up and I'm free I go to wake up and see them again
#
# They'll tell me that my dreams are just dreams and that dreams mean nothing because when the sun sets
#
# The stars will be in my dreams and I'll forget them
#
# The world won't know what to do with me... you're free, now, I'm home, where can I sleep now?
#
# Where can I go when the moon's out and I dream about things I can't dream about anymore
#
# When I'm sad I'll cry, you're just sad but you can't take it away
#
# (I hope it lasts till the day I die.) [Chorus] Dream of freedom...
#
# Dream of free, I dreamed about it and it worked out. Dream of freedom. I don't give up hope yet
#
# Dream of freedom, I won't let it stop me
#
# I can see it shining around the corner.
#
# There's nothing left to do
#
# Now that's freedom. Dream of freedom.
#
# I know it's possible. I know.
#
# There's more freedom, I can't wait for it
#
# I want to make the dream so real
#
# I want to make my dreams so true, I want to feel free
#
# But I'll do what I have to, and that's all that I need
#
# DREAMS...I WANTED IT ALL TO HAVE BEEN HERE, NOW!
#
# WHEN THE SUNSET IS OVER, EACH SONG IS OVER
#
# FREETOWN…
#
# WHEN I OPEN MY WINDER, I HAVE
#
# THE NIGHT…WHEN THE SAME SONG CAN COUNT FOR MORE
#
# AND SOUNDS ARE LIKE A CIRCLE, ALL THE HAPPINESS OF IT ALL IS OVER
#
# I KNOW…
#
# IT IS THE SONG OF FREELOADMENT!
#
#
# I will sing for your freedom;
#
# When all of my dream came true…
#
# I want a dream that brings me joy,
#
# For all of my happy moments have been filled with you so.
#
# It's just like the dream I had in college… it's just as beautiful as the dreams I'm now having...
#
#
# Just as beautiful. Just as beautiful. I will stay in your wake
#
# As long as you need me right now. I want you here
#
# To be in my dreams
#
# FREETOWN!
#
# Wake up and look at the sky… to see where it's shining,
#
# To hear and to feel the wind, to be free…
#
# And

# %%
#Set the model to evaluate to run prompts on the model for generation
model.eval()

prompt_text = "The underground passage led to heaven"

#Convert the prompt text to tokens and add the attention mask
input_ids = tokenizer(prompt_text, return_tensors = "pt").input_ids
attention_mask = tokenizer(
    prompt_text, return_tensors="pt"
).attention_mask

#Send converted prompt and attention mask to GPU
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)


#Generate the output from the model based on the parameter set here
output = model.generate(
    input_ids = input_ids,
    attention_mask = attention_mask,
    pad_token_id = tokenizer.pad_token_id,
    max_length = 1024,
    num_beams = 10,
    min_length = 1000,
    temperature = 2.5,
    top_k = 50,
    do_sample = True,
)


generated_text = tokenizer.decode(output[0],skip_special_tokens = True)

print(generated_text)
# Out:
# The underground passage led to heaven and the heavens. It was all that remained of the city.
#
#
# After the passage was finally closed, it was decided to leave the city and explore the area in its entirety, and to make sure no one would ever see it again.
#
#
# One day after sunset, the city fell silent. No one could understand what had happened.
#
#
# One day later, when the sun's rays were beginning to reach the city, a man made a sound with his voice. He stood by the entrance of the underground passage, and it seemed that he had been heard. He looked around, and there he saw someone standing in the middle of the passage.
#
#
# "I've been here before," he muttered, and walked over to the person.
#
#
# "What have you been doing?" the person replied.
#
#
# "I've been talking to you," the man said.
#
#
# "Well," the man said, "I'm afraid I don't believe you."
#
#
# "No, you're quite right," the man replied.
#
#
# The person nodded.
#
#
# The person walked away. It was then that the man realized he was being watched.
#
#
# "Wait," the person whispered to himself. "Why did you go and talk to me? Who did this to me?"
#
#
# "Well," the person began. "I'm afraid I don't know," he explained. "I've been here before."
#
#
# "Why didn't you go and tell me?" the person inquired.
#
#
# The person answered, "I didn't know who you were then."
#
#
# "Why did you wait until now?" the person asked.
#
#
# "Well, because you're trying to protect me now," the person said. "If you'd let me go, then I could have helped you."
#
#
# "But if I let you go now," the person continued, "then I'm going to hurt you."
#
#
# The person was silent for a long time.
#
#
# The man finally said, "I'll go and tell you."
#
#
# He walked out of the underground passage, and out of the darkness, into the light. He opened a door in the darkness and walked inside it. Inside, he turned on the light to reveal that it was dark inside the room. The man walked around to look around again, but there was nothing else.
#
#
# "Come on," the man said to himself. "Let's get out of here."
#
#
# He walked out of the room and into the light again. There were now three people inside. One of them was staring at him, and the other two were staring back. The man stood up, walked over to them, and asked, "How did you know I was here? What did you see me for?"
#
#
# The one who answered was silent for a long time after that.
#
#
# "What did you see?" the man asked.
#
#
# "I saw you. You saw me."
#
#
# "Where was I?" the one who stared back asked.
#
#
# "In your cell."
#
#
# "In a cell?"
#
#
# "In your cell. It was in the middle of the city, on a rooftop."
#
#
# The one who stared at him began to cry out in pain.
#
#
# "Are you okay?" the man asked.
#
#
# The one who stared back said, "I'm fine. I just wanted to tell you that I am here to protect you."
#
#
# The one who cried out in pain began to cry.
#
#
# The man took the one who cried out of his sight.
#
#
# "What did you do to me?" the man asked again.
#
#
# The one who stared back answered, "I just wanted to know what you did for me."
#
#
# "Why?" the man continued to cry.
#
#
# The one who stared back said, "I just wanted to tell you what you did for me."
#
#
# The man walked over to the one who looked at him and asked, "Did you kill her?"
#
#
# The one who stared back said, "No, she wasn't dead. She was just asleep."
#
#
# "Do you know what happened to her?" the man asked.
#
#
# The one who stared back said, "No."
#
#
# "She's still here?" the man asked.
#
#
# The one who stared back replied, "Yes."
#
#
# "Why are you still here?" the man asked.
#
#
# The one who stared back said, "I'm still here to protect you from evil."
#
#
# "What's evil about evil?" the man asked.
#
#
# The one he stared at answered, "Evil is killing."
#
#
# "Do you believe in the devil?" the man asked.
#
#
# The one who gazed back answered, "I don't believe in the devil."
#
#
# The one who stared at him answered, "Then what is the devil?"
#
#
# The one who stared at him

# %%
model.eval()

prompt_text = "The ray gun vaporized the entire town under the sea"

#Convert the prompt text to tokens and add the attention mask
input_ids = tokenizer(prompt_text, return_tensors = "pt").input_ids
attention_mask = tokenizer(
    prompt_text, return_tensors="pt"
).attention_mask

#Send converted prompt and attention mask to GPU
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)


#Generate the output from the model based on the parameter set here
output = model.generate(
    input_ids = input_ids,
    attention_mask = attention_mask,
    pad_token_id = tokenizer.pad_token_id,
    max_length = 1024,
    num_beams = 10,
    min_length = 1000,
    temperature = 3.5,
    top_k = 50,
    do_sample = True,
)


generated_text = tokenizer.decode(output[0],skip_special_tokens = True)

print(generated_text)
# Out:
# The ray gun vaporized the entire town under the sea. "And that's the only thing I have to look forward to this time." The air began shaking violently, and everyone seemed to feel a strange sensation.
# Ryuichi opened his eyes. He saw that even though he was still floating upside down, there was still a single light shining through him.
# "Uhh… Huh? What happened? I just fell off." It was an odd feeling.
# Just then, he heard a faint cry from the town, and froze in place. He didn't feel any pressure, so there wasn't any sense of danger.
# He didn't expect to be greeted by someone who didn't recognize him at all, so Yuigahama couldn't be a threat. "How about you give up and go." With that she left Yuigahama's room, and started on her way. "I'll deal with the rest later on..."
# "That's not it." She didn't stop her steps, but she looked down at the floor.
# "So you want me to have sex with you?" Was that a joke?
# "... Eh, it might be a good idea." He muttered, as if he regretted saying that.
# "That would be an amazing idea… but you have a girlfriend, so you must be careful of your own feelings. That can't be easy for you, huh?" Even if the pain could be felt by her body, it wasn't like she could even feel it inside.
# "Oh? What does it sound like? You want to see her too?"
# Even with her not having sex, he was still too weak for this world. Perhaps because he was too weak to get his heart back to life, he was unable to resist her advances.
# That was why.
# As a human woman, her body was strong. Even if the feelings she experienced while on this plane didn't affect her with his, she still felt them. If he went back to this world, he could easily get rid of it as well. But she did want to become a man, and she understood that she had to make him understand that she needed to use her beauty to attract men. If he did the opposite, she wouldn't want him anymore.
# She thought he was a worthless person, after all. If he wasn't able to return home to this world, wouldn't that mean losing her virginity to him by force?
# He didn't need to be ashamed of having her as a girlfriend. That was why he wanted to return.
# But what if that was all a plan?
# She had tried to talk about that with a friend, and she wasn't supposed to say that in front of the others, of course. But she wasn't talking with Yuigahama now, and he wasn't able to think clearly about what to do. She would be unable to understand the pain she caused him. He wasn't even aware that he even wanted to lose his virginity. This was only what he didn't have control over anymore; there was no choice left, regardless of whether she would be allowed to use magic to be with him. It wasn't even close.
#
# So we've spent the last three volumes looking back along this journey on Vingarlion to tell us something he didn't say at his first meeting. As he later notes "When he left the meeting it was as if she were dead." However at the beginning he states that even if that were true this was an experience that could last even years. It would come when he would be ready... as indeed he was when it would. For the moment of his return of power it took place for this very instant only as the light in the darkness of his soul and mind and his thoughts came into physical form to meet that power, this power which

# %%
model.eval()

prompt_text = "Great Scott!"

#Convert the prompt text to tokens and add the attention mask
input_ids = tokenizer(prompt_text, return_tensors = "pt").input_ids
attention_mask = tokenizer(
    prompt_text, return_tensors="pt"
).attention_mask

#Send converted prompt and attention mask to GPU
input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)


#Generate the output from the model based on the parameter set here
output = model.generate(
    input_ids = input_ids,
    attention_mask = attention_mask,
    pad_token_id = tokenizer.pad_token_id,
    max_length = 1024,
    num_beams = 10,
    min_length = 1000,
    temperature = 6.5,
    top_k = 50,
    do_sample = True,
)


generated_text = tokenizer.decode(output[0],skip_special_tokens = True)

print(generated_text)
# Out:
# Great Scott! I'm on a roll this week since I think you've added a number of people that should help make me a better contributor! Let's hear out some questions about what makes your company tick so we can make every day easier for you when you get up before dawn. We'll hear your answers as to what makes us worth investing in and what should make up for the fact you'll spend less time getting up from home than you might like! Thanks, Dan
#
# I've been thinking how to help others get work done for 3 months. So much. I am super excited and thankful to think I might become the creator of our own company, but I've spent the last two years building a team and making money and starting a company all to do with things other than technology to achieve those ends. There are things I hope and believe will change how you get accomplished with your goals, because I always felt like the best outcome of a creative outlet is working at it harder. It was the most powerful reason why I'm pursuing my tech dreams, but you are right, if you can't be happy in technology for too long without spending enough time in software, your priorities will change. So it is not a place for failure. The thing I've found with getting started, was that the more technical, the worse people wanted to be so they would spend the extra time and energy in the tech side of things and don't even try. Once you start to fall away from the technical you fall into the technical side, but if your company doesn't seem to have an edge for everyone and things are going smoothly then they will see the value that tech offers from people who understand the challenges of building software from their perspective. That is where I hope my work and what we accomplish comes from, not my software development side. This can be achieved through education or just learning by being around it first. Just having someone you can see at the table (at the table they work for) can make the difference when it's time to focus. So I work on a team of two people (and have one person in tech who writes a blog) so I'm trying to develop this into a product for people who can create something quickly and share their thoughts. When I have something going you can take it with you to share with a group of people to work from for the next 2 days. It will save you from the stress from going through a lot of details alone. I can always email you after working and share more of what you're seeing and have fun doing it all the way with anyone! And it gets done with less time and has fewer challenges! I hope your goal of having a "product" and working around the technology side gives you that spark of desire. It is not uncommon to be the one doing that, I just needed to get to where it comes from with another outlet for that. I see what is happening here, I am not interested in wasting the opportunities, I am only going to concentrate on focusing in the "product-less part." It is why you've chosen to put this time in at a startup! That is one of only two reasons I would even contemplate going into the software development arena, and for you, I will now spend some time on a personal blog and maybe some writing/writing/design so everyone can think in a positive fashion. :) I have done my due diligence on your situation, which is great, I appreciate your company so much in the business/tech world where I work, because we both care. So let's continue the conversation, Dan, thanks and best wishes from me to you in my next step of wanting to help others succeed. Your work is amazing! And not only does your work put more people out of work then I ever did before (I had to stop before I had 100% of my time to myself working in software until I got the passion and dedication from my job that I needed to create for myself). We all have to work to give as many in less time as our ability. The time is what makes progress and we all know we can help people, but so what? Because the more time you give others the choice to work a 4 day weekend than you will have if they only work two? I'm all for allowing people choose their schedule, but that's assuming that these choices don't compromise what is actually good for all. So as to your time being valuable, it is always appreciated if you put in one day every 2 weeks or so of productivity, but just remember you're doing so often. With that said, this brings up one of a few possible areas of future development, I am happ ...
